# %%
import os
import pandas as pd
import numpy as np

from tsfresh import extract_features
from tsfresh.feature_extraction import MinimalFCParameters

# %%
input_dir_path = '../analysis/ready_group/face'
output_dir = '../extracted_features/computed_ready/face'

# %%
for filename in os.listdir(input_dir_path):
    print(filename)
    if filename == '.ipynb_checkpoints':
        continue  # Skip the .ipynb_checkpoints directory

    df_id = filename.split('_')[0]
    input_df = pd.read_csv(os.path.join(input_dir_path, filename))
    input_df = input_df.apply(pd.to_numeric, errors='coerce')
    input_df.fillna(0, inplace=True)

    input_df['window'] = input_df['window'].astype(int)

    # Increment 'window' column by 1
    input_df['window'] = input_df['window'] + 1


    settings = MinimalFCParameters()

    neutral = extract_features(input_df, column_id='neutral', column_sort='window', default_fc_parameters=settings)
    neutral.dropna(axis=1, how='all', inplace=True)

    happy = extract_features(input_df, column_id='happy', column_sort='window', default_fc_parameters=settings)
    happy.dropna(axis=1, how='all', inplace=True)

    sad = extract_features(input_df, column_id='sad', column_sort='window', default_fc_parameters=settings)
    sad.dropna(axis=1, how='all', inplace=True)

    angry = extract_features(input_df, column_id='angry', column_sort='window', default_fc_parameters=settings)
    angry.dropna(axis=1, how='all', inplace=True)
    # 
    fearful = extract_features(input_df, column_id='fearful', column_sort='window', default_fc_parameters=settings)
    fearful.dropna(axis=1, how='all', inplace=True)

    disguisted = extract_features(input_df, column_id='disgusted', column_sort='window', default_fc_parameters=settings)
    disguisted.dropna(axis=1, how='all', inplace=True)

    surprised = extract_features(input_df, column_id='surprised', column_sort='window', default_fc_parameters=settings)
    surprised.dropna(axis=1, how='all', inplace=True)

    neutral_change = extract_features(input_df, column_id='neutral_change', column_sort='window', default_fc_parameters=settings)
    neutral_change.dropna(axis=1, how='all', inplace=True)

    happy_change = extract_features(input_df, column_id='happy_change', column_sort='window', default_fc_parameters=settings)
    happy_change.dropna(axis=1, how='all', inplace=True)

    sad_change = extract_features(input_df, column_id='sad_change', column_sort='window', default_fc_parameters=settings)
    sad_change.dropna(axis=1, how='all', inplace=True)

    angry_change = extract_features(input_df, column_id='angry_change', column_sort='window', default_fc_parameters=settings)
    angry_change.dropna(axis=1, how='all', inplace=True)

    fearful_change = extract_features(input_df, column_id='fearful_change', column_sort='window', default_fc_parameters=settings)
    fearful_change.dropna(axis=1, how='all', inplace=True)

    disguisted_change = extract_features(input_df, column_id='disgusted_change', column_sort='window', default_fc_parameters=settings)
    disguisted_change.dropna(axis=1, how='all', inplace=True)
    
    surprised_change = extract_features(input_df, column_id='surprised_change', column_sort='window', default_fc_parameters=settings)
    surprised_change.dropna(axis=1, how='all', inplace=True)

    df1 = neutral.reset_index(drop=True)
    df2 = happy.reset_index(drop=True)
    df3 = sad.reset_index(drop=True)
    df4 = angry.reset_index(drop=True)
    df5 = fearful.reset_index(drop=True)
    df6 = disguisted.reset_index(drop=True)
    df7 = surprised.reset_index(drop=True)
    df8 = neutral_change.reset_index(drop=True)
    df9 = happy_change.reset_index(drop=True)
    df10 = sad_change.reset_index(drop=True)
    df11 = angry_change.reset_index(drop=True)
    df12 = fearful_change.reset_index(drop=True)
    df13 = disguisted_change.reset_index(drop=True)
    df14 = surprised_change.reset_index(drop=True)
    
    main_df = input_df.reset_index(drop=True)

    extracted_face_feat = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14], axis=1)
    face_features = pd.concat([main_df, extracted_face_feat], axis=1)
    

    #cols_to_drop = []
    #for col in cog_df_features.columns:
    #    if cog_df_features[col].nunique() == 1:
    #        cols_to_drop.append(col)

    #cog_df_features.drop(cols_to_drop, axis=1, inplace=True)

    output_filename = f"{df_id}_face_features.csv"
    face_features.to_csv(os.path.join(output_dir, output_filename), index=False)
# Out:
# 10015_faceapi.csv
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 34.25it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 32.81it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 36.68it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 28.80it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 28.35it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 31.54it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 30.32it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 33.33it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 33.48it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 24.15it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 30.49it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 34.63it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 33.57it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 32.59it/s]
# 10020_faceapi.csv
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 33.56it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 35.83it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 35.59it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 38.26it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 28.06it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 35.01it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 35.01it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 41.01it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 33.21it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 33.78it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 33.50it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 28.01it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 37.89it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 37.57it/s]
# f10005_faceapi.csv
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 34.46it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 46.10it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 60.06it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 48.03it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 67.96it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 40.69it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 49.52it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 42.63it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 60.00it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 46.49it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 59.09it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 45.35it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 57.12it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 47.10it/s]
# 10006_faceapi.csv
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 32.07it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 36.08it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 33.29it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 24.66it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 29.99it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 32.79it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 35.21it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 33.86it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 27.41it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 25.62it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 28.08it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 31.92it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 35.46it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 34.22it/s]
# 10014_faceapi.csv
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 31.08it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 26.31it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 23.57it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 25.25it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 25.73it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 27.15it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 30.71it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 32.14it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 33.51it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 35.33it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 25.24it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 32.32it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 32.80it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 35.00it/s]
# f10001_faceapi.csv
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 32.73it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 33.80it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 31.01it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 24.17it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 33.50it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 33.33it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 29.56it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 31.27it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 25.74it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 21.75it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 26.83it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 30.13it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 29.54it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 34.40it/s]
# f10021_faceapi.csv
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 31.09it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 34.48it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 35.23it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 30.10it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 26.66it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 34.88it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 35.67it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 38.96it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 31.00it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 27.05it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 20.29it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 20.89it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 21.50it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 20.33it/s]
# 10009_faceapi.csv
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 25.62it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 33.20it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 26.39it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 35.50it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 27.62it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 32.71it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 26.64it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 28.85it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 23.11it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 32.22it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 21.99it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 28.64it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 37.52it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 28.36it/s]
# f10008_10009_faceapi.csv
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 21.95it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 20.49it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 36.98it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 36.62it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 48.29it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 37.95it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 37.56it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 34.37it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 42.49it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 29.39it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 31.45it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 40.04it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 30.45it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 35.17it/s]
# f10006_faceapi.csv
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 29.46it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 24.76it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 22.41it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 28.50it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 27.41it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 28.59it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 26.65it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 26.51it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 29.78it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 27.86it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 23.89it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 24.54it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 27.80it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 29.99it/s]
# f10007_faceapi.csv
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 28.05it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 31.12it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 27.81it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 28.35it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 24.55it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 23.73it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 21.86it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 27.09it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 26.33it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 28.07it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 27.68it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 22.65it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 30.28it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 21.37it/s]
# 10007_faceapi.csv
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 28.66it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 26.60it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 27.54it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 28.60it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 24.71it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 23.70it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 24.58it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 27.40it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 27.52it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 28.32it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 26.61it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 24.74it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 26.48it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 23.65it/s]
# 10018_faceapi.csv
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 31.42it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 27.87it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 29.08it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 29.42it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 31.65it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 31.60it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 26.51it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 32.00it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 29.27it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 32.71it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 28.59it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 29.30it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 29.44it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 30.03it/s]
# f10081_faceapi.csv
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 26.15it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 27.74it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 24.88it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 21.85it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 20.27it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 21.06it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 25.83it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 25.43it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 27.39it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 27.72it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 27.78it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 26.54it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 26.96it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 24.72it/s]
# 10017_faceapi.csv
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 36.21it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 57.23it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 59.68it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 49.79it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 43.40it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 54.69it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 40.93it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 49.26it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 33.87it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 49.86it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 39.25it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 50.36it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 41.50it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 48.82it/s]
# f10041_faceapi.csv
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 25.05it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 27.34it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 29.28it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 27.59it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 26.17it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 26.44it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 19.88it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 26.10it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 23.64it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 17.74it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 15.65it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 17.90it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 19.50it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 23.06it/s]
# f10051_faceapi.csv
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 21.03it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 25.68it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 24.93it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 26.27it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 25.99it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 25.34it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 22.09it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 20.86it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 21.26it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 27.98it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 25.28it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 26.30it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 27.05it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 22.49it/s]
# 10003_faceapi.csv
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 29.95it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 25.21it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 28.16it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 24.95it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 20.44it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 20.76it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 19.77it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 22.56it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 23.18it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 22.07it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 18.93it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 19.92it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:01<00:00, 19.30it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 20.63it/s]
# f10071_faceapi.csv
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 25.79it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 26.55it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 27.19it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 29.62it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 27.68it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 29.79it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 26.42it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 26.11it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 23.88it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 22.25it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 21.71it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 23.90it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 23.94it/s]
# Feature Extraction: 100%|███████████████████████████████████████████████████| 20/20 [00:00<00:00, 26.00it/s]
# .ipynb_checkpoints
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# Cell In[9], line 4
#       2 print(filename)
#       3 df_id = filename.split('_')[0]
# ----> 4 input_df = pd.read_csv(os.path.join(input_dir_path, filename))
#       5 input_df = input_df.apply(pd.to_numeric, errors='coerce')
#       6 input_df.fillna(0, inplace=True)
#
# File ~/Dokumenter/Master/jupyter/environment/lib/python3.8/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/Dokumenter/Master/jupyter/environment/lib/python3.8/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~/Dokumenter/Master/jupyter/environment/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~/Dokumenter/Master/jupyter/environment/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~/Dokumenter/Master/jupyter/environment/lib/python3.8/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# IsADirectoryError: [Errno 21] Is a directory: '../analysis/ready_group/face/.ipynb_checkpoints'
